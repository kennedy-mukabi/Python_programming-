# %% [markdown]
# # Using the mbox.txt return a dictionary with all the emails
# # with the number of occurrence they occur  on all the TO and FROM emails.

# %%
fhandle = open("mbox.txt")

# %%
count=0
mail_dict={}
fhandle=open("mbox.txt")
for f in fhandle:
    if (f.startswith("From:")) or (f.startswith("To")):
        count=count+1
        print(f)
         for p in f:
            if f not in mail_dict:
                mail_dict[f]=1
            else:
                worddict[fh]=worddict[fh]+1
# Out:
# To: source@collab.sakaiproject.org
#
# From: stephen.marquard@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# From: louis@media.berkeley.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: wagnermr@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# ...

# %%
mail_dict=dict()

# %%
mail_dict
# Out:
# {}
