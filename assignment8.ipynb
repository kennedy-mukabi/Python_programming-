# %% [markdown]
# # Using the mbox.txt return a tuple with 10 emails
# # with the highest number of occurrence on all the TO and FROM emails.

# %%
fhandle = open("mbox.txt")

# %%
count=0
mail_dict={}
fhandle=open("mbox.txt")
for f in fhandle:
    if (f.startswith("From:")) or (f.startswith("To:")):
        count=count+1
        print(f)
        for p in f:
            if f not in mail_dict:
                mail_dict[f]=1
            else:
                mail_dict[f]=mail_dict[f]+1
# Out:
# To: source@collab.sakaiproject.org
#
# From: stephen.marquard@uct.ac.za
#
# To: source@collab.sakaiproject.org
#
# From: louis@media.berkeley.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: rjlowe@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: cwen@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: gsilver@umich.edu
#
# To: source@collab.sakaiproject.org
#
# From: wagnermr@iupui.edu
#
# To: source@collab.sakaiproject.org
#
# From: zqian@umich.edu
#
# To: source@collab.sakaiproject.org
#
# ...

# %%
mail_dict
# Out:
# {'To: source@collab.sakaiproject.org\n': 57540,
#  'From: stephen.marquard@uct.ac.za\n': 957,
#  'From: louis@media.berkeley.edu\n': 620,
#  'From: zqian@umich.edu\n': 3630,
#  'From: rjlowe@iupui.edu\n': 1817,
#  'From: cwen@iupui.edu\n': 3297,
#  'From: gsilver@umich.edu\n': 576,
#  'From: wagnermr@iupui.edu\n': 1075,
#  'From: antranig@caret.cam.ac.uk\n': 558,
#  'From: gopal.ramasammycook@gmail.com\n': 900,
#  'From: david.horwitz@uct.ac.za\n': 2010,
#  'From: ray@media.berkeley.edu\n': 609,
#  'From: mmmay@indiana.edu\n': 3864,
#  'From: stuart.freeman@et.gatech.edu\n': 595,
#  'From: tnguyen@iupui.edu\n': 144,
#  'From: chmaurer@iupui.edu\n': 2675,
#  'From: aaronz@vt.edu\n': 1640,
#  'From: ian@caret.cam.ac.uk\n': 2054,
#  'From: csev@umich.edu\n': 399,
#  'From: jimeng@umich.edu\n': 2139,
#  'From: josrodri@iupui.edu\n': 700,
#  'From: knoop@umich.edu\n': 110,
#  'From: bkirschn@umich.edu\n': 600,
#  'From: dlhaines@umich.edu\n': 1800,
#  'From: hu2@iupui.edu\n': 140,
# ...

# %%
a=tuple([mail_dict])

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-a5a87226fd73> in <module>
# ----> 1 print(a[25])
#
# IndexError: string index out of range
